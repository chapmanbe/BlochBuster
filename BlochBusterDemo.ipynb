# %%
from BlochBuster import BlochBuster
from IPython.display import Image, display

# %%
BlochBuster("config/SE.yaml", 1, False)
# Out:
# Saving frame 1/727 as "./tmp/0001.png"
# Saving frame 2/727 as "./tmp/0002.png"
# Saving frame 3/727 as "./tmp/0003.png"
# Saving frame 4/727 as "./tmp/0004.png"
# Saving frame 5/727 as "./tmp/0005.png"
# Saving frame 6/727 as "./tmp/0006.png"
# Saving frame 7/727 as "./tmp/0007.png"
# Saving frame 8/727 as "./tmp/0008.png"
# Saving frame 9/727 as "./tmp/0009.png"
# Saving frame 10/727 as "./tmp/0010.png"
# Saving frame 11/727 as "./tmp/0011.png"
# Saving frame 12/727 as "./tmp/0012.png"
# Saving frame 13/727 as "./tmp/0013.png"
# Saving frame 14/727 as "./tmp/0014.png"
# Saving frame 15/727 as "./tmp/0015.png"
# Saving frame 16/727 as "./tmp/0016.png"
# Saving frame 17/727 as "./tmp/0017.png"
# Saving frame 18/727 as "./tmp/0018.png"
# Saving frame 19/727 as "./tmp/0019.png"
# Saving frame 20/727 as "./tmp/0020.png"
# Saving frame 21/727 as "./tmp/0021.png"
# Saving frame 22/727 as "./tmp/0022.png"
# Saving frame 23/727 as "./tmp/0023.png"
# Saving frame 24/727 as "./tmp/0024.png"
# ...

# %%
display(Image(data="./outSE_3D.gif"))
display(Image(data="outSE_xy.gif"))
display(Image(data="outSE_z.gif"))
